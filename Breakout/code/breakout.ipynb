# %% [markdown]
# ## Install Dependencies

# %%
# %tensorflow_version 1.x

# %%
# !git clone https://github.com/openai/baselines.git

# %%
cd baselines

# %%
pip install -e .

# %% [markdown]
# ## Training Scripts

# %%
# !python3 -m baselines.run --alg=a2c --env=BreakoutNoFrameskip-v4 --num_timesteps=1e6 --save_path=models/breakout_a2c --log_path=logs/Breakout_a2c

# %%
# !python3 -m baselines.run --alg=ppo2 --env=BreakoutNoFrameskip-v4 --num_timesteps=1e6 --save_path=models/breakout_ppo2 --log_path=logs/Breakout_ppo2

# %%
# !python3 -m baselines.run --alg=trpo_mpi --env=BreakoutNoFrameskip-v4 --num_timesteps=1e6 --save_path=models/breakout_trpo_mpi --log_path=logs/Breakout_trpo_mpi

# %% [markdown]
# ## Inference Scripts

# %%
# !python3 -m baselines.run --alg=a2c --env=BreakoutNoFrameskip-v4 --num_timesteps=0 --load_path=models/breakout_a2c --play

# %%
# !python3 -m baselines.run --alg=ppo2 --env=BreakoutNoFrameskip-v4 --num_timesteps=0 --load_path=models/breakout_ppo2 --play

# %%
# !python3 -m baselines.run --alg=trpo_mpi --env=BreakoutNoFrameskip-v4 --num_timesteps=0 --load_path=models/breakout_trpo_mpi --play
